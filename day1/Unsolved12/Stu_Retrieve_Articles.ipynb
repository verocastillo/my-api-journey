# %%
# Dependencies
import requests
import json
from config import api_key
from pprint import pprint

url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Store a search term
queryterm = "liberals"

# Search for articles published between a begin and end date
begin_date = "20200101"

end_date= "20201231"

# Build url
query_url = url + "api-key=" + api_key + "&q=" + queryterm + "&begin_date=" + begin_date + "&end_date=" + end_date

# %%
# Retrieve articles
articles = requests.get(query_url).json()
articles_list = articles["response"]["docs"]
pprint(articles_list)
# Out:
# [{'_id': 'nyt://article/ff424197-7b47-5b27-9e92-0f3a395bb3d9',
#   'abstract': 'Prime Minister Scott Morrison came under fire this week for '
#               'abruptly interrupting a female senior minister who was asked '
#               'what it’s like to be a woman in Parliament.',
#   'byline': {'organization': None,
#              'original': 'By Damien Cave',
#              'person': [{'firstname': 'Damien',
#                          'lastname': 'Cave',
#                          'middlename': None,
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 1,
#                          'role': 'reported',
#                          'title': None}]},
#   'document_type': 'article',
#   'headline': {'content_kicker': None,
#                'kicker': None,
#                'main': 'Australia’s Struggle With ‘Bonk Bans’ and '
#                        '‘Manterruptions’',
#                'name': None,
# ...

# %%
# BONUS: How would we get 30 results? 
# HINT: Look up the page query param
# Store a search term
queryterm = "liberals"

# Search for articles published between a begin and end date
begin_date = "20200101"

end_date= "20201231"

# Select a number of articles (desired number/10 -1)
page= "2"

# Build url
query_url = url + "api-key=" + api_key + "&q=" + queryterm + "&page=" + page + "&begin_date=" + begin_date + "&end_date=" + end_date 

articles = requests.get(query_url).json()
articles_list = articles["response"]["docs"]
pprint(articles_list)
# Out:
# [{'_id': 'nyt://article/9d1c2c5c-485b-5281-bf4f-17c521597e75',
#   'abstract': 'The George Floyd protests expose the fault lines in '
#               'metropolitan America.',
#   'byline': {'organization': None,
#              'original': 'By Ross Douthat',
#              'person': [{'firstname': 'Ross',
#                          'lastname': 'Douthat',
#                          'middlename': None,
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 1,
#                          'role': 'reported',
#                          'title': None}]},
#   'document_type': 'article',
#   'headline': {'content_kicker': None,
#                'kicker': None,
#                'main': 'Crisis in the Liberal City',
#                'name': None,
#                'print_headline': None,
#                'seo': None,
#                'sub': None},
#   'keywords': [{'major': 'N',
#                 'name': 'subject',
# ...
